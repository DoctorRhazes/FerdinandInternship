# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
html = urlopen("http://www.pythonscraping.com/pages/page3.html")
bsObj = BeautifulSoup(html,"lxml")

print(bsObj.find("img",{"src":"../img/gifts/img1.jpg"
}).parent.previous_sibling.get_text())
# Out:
# $15.00

# %% [markdown]
# "parent" von einem Tag suchen:
# print(bsObj.find("img",{"src":"../img/gifts/img1.jpg"
# }).parent.previous_sibling.get_text())
#
#  Struktur: tr td 15$ td img src)...
#  img src ausgewählt
#  parent: td ausgewählt
#  previous sibling: td davor (td 15$) ausgewählt

# %% [markdown]
# "regular String" -> String der mit linearen Regeln beschrieben werden kann
# Beispiele: aa* -> a mindestens einmal
# bbbb -> b 4 mal
# (b | ) -> optional b
# (cc)* -> c eine gerade Anzahl an malen dh eine unbestimmte Anzahl an cc
# a* -> a 0 bis unendlich mal
#
# ////////extrem nützliche Website:
# http://www.regexpal.com/
# //////////////////REGEX TESTEN!!!
# REGEX Bauteile:
#
# [\.]+ /////ein Punkt 1x-inf
#
# [A-Z\+]+ /////A-Z ODER + 1x-inf
#
# (A-Z|\+) /////"A-Z" oder "+" 1x
#
# [A-Za-z]+ ///// Buchstabe groß/klein 1x-inf
#
# ([A-Z]|\+) /////Buchstabe groß/klein OR "+" 1x-inf
#
# (a*b) ///// a 0x-inf UND b einmal
#
# a{2,3} ///// a zwei bis dreimal
#
# ^a ///// a am Anfang des gesamten Ausdruckes
#
# [A-Z]+[0-9]+$ ///// Großbuchstaben 1x-inf Zahlen 1x-inf ENDE des gesamten Ausdruckes
#
# a$ ///// a am Ende des gesamten Ausdruckes
#
# ((?![a]).) ///// NICHT-a mit einem Symbol dran eg "b"
#
# \ ///// wichtig für \. \\ etc

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
WebsiteHTMLContent = urlopen("https://pythonscraping.com/pages/warandpeace.html")
BSObjekt = BeautifulSoup(WebsiteHTMLContent.read(),"lxml")
print(BSObjekt)
# Out:
# <html>
# <head>
# <style>
# .green{
# 	color:#55ff55;
# }
# .red{
# 	color:#ff5555;
# }
# #text{
# 	width:50%;
# }
# </style>
# </head>
# <body>
# <h1>War and Peace</h1>
# <h2>Chapter 1</h2>
# <div id="text">
# "<span class="red">Well, Prince, so Genoa and Lucca are now just family estates of the
# Buonapartes. But I warn you, if you don't tell me that this means war,
# if you still try to defend the infamies and horrors perpetrated by
# that Antichrist- I really believe he is Antichrist- I will have
# nothing more to do with you and you are no longer my friend, no longer
# my 'faithful slave,' as you call yourself! But how do you do? I see
# I have frightened you- sit down and tell me all the news.</span>"
# <p></p>
# It was in July, 1805, and the speaker was the well-known <span class="green">Anna
# Pavlovna Scherer</span>, maid of honor and favorite of the <span class="green">Empress Marya
# ...

# %% [markdown]
# Ausdruck von einer Website, über ein BeautifulSoup Objekt

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen

HTMLCode = urlopen("https://www.pythonscraping.com/pages/page3.html")
BSObjekt = BeautifulSoup(HTMLCode,"lxml") # Code direkt in BS Objekt umgewandelt

kind =  BSObjekt.find("table",{"id":"giftList"}).children
for i in kind:
    print(i)
# Out:
# <tr><th>
# Item Title
# </th><th>
# Description
# </th><th>
# Cost
# </th><th>
# Image
# </th></tr>
#
#
# <tr class="gift" id="gift1"><td>
# Vegetable Basket
# </td><td>
# This vegetable basket is the perfect gift for your health conscious (or overweight) friends!
# <span class="excitingNote">Now with super-colorful bell peppers!</span>
# </td><td>
# $15.00
# </td><td>
# <img src="../img/gifts/img1.jpg"/>
# </td></tr>
#
#
# <tr class="gift" id="gift2"><td>
# Russian Nesting Dolls
# </td><td>
# Hand-painted by trained monkeys, these exquisite dolls are priceless! And by "priceless," we mean "extremely expensive"! <span class="excitingNote">8 entire dolls per set! Octuple the presents!</span>
# </td><td>
# $10,000.52
# </td><td>
# <img src="../img/gifts/img2.jpg"/>
# </td></tr>
#
#
# <tr class="gift" id="gift3"><td>
# Fish Painting
# </td><td>
# ...

# %% [markdown]
# Ausdruck sämtlicher direkter  Unterpunkte von <table> Tags

# %%
tdTags = BSObjekt.findAll(lambda tr: len(tr.attrs)==2)
print(tdTags[0])
# Out:
# <img src="../img/gifts/logo.jpg" style="float:left;"/>

# %% [markdown]
# Lambda Funktion: sucht alle <tr> Tags die jeweils zwei Attribute besitzen

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

html = urlopen("http://en.wikipedia.org/wiki/Kevin_Bacon")
bsObj = BeautifulSoup(html,"lxml")

for link in bsObj.find("div", {"id":"bodyContent"}).findAll("a",
href=re.compile("^(/wiki/)((?!:).)*$")):
    if 'href' in link.attrs:
        print(link.attrs['href'])
# Out:
# /wiki/Kevin_Bacon_(disambiguation)
# /wiki/San_Diego_Comic-Con
# /wiki/Philadelphia
# /wiki/Pennsylvania
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# /wiki/Footloose_(1984_film)
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Sleepers
# /wiki/The_Woodsman_(2004_film)
# /wiki/Fox_Broadcasting_Company
# /wiki/The_Following
# /wiki/Golden_Globe_Award
# /wiki/Screen_Actors_Guild_Awards
# /wiki/Primetime_Emmy_Award
# /wiki/The_Guardian
# /wiki/Academy_Award
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Social_networks
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/SixDegrees.org
# /wiki/Philadelphia
# /wiki/Edmund_Bacon_(architect)
# /wiki/Pennsylvania_Governor%27s_School_for_the_Arts
# /wiki/Bucknell_University
# /wiki/Glory_Van_Scott
# /wiki/Kevin_Bacon_filmography
# /wiki/Circle_in_the_Square
# /wiki/Nancy_Mills
# /wiki/Cosmopolitan_(magazine)
# ...

# %% [markdown]
# Kevin Bacon Wikipedia Seite wird nach Artikellinks durchsucht:
# bsObj.find("div", {"id":"bodyContent"}) -> Tag div mit dem attribut id="bodyContent"
# .findAll("a",
# href=re.compile("^(/wiki/)((?!:).)*$")):
# -> alle Tags <a> mit dem Attribut "href" , Inhalt: ein link der mit /wiki/ beginnt, dann Ausdrucksgruppe:
# kEINE Semikolons aber unbestimmte Anzahl an Zeichen bis zum Ende

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import datetime
import random
import re
random.seed(datetime.datetime.now())

def getLinks(articleUrl):
    html = urlopen("http://en.wikipedia.org"+articleUrl)
    bsObj = BeautifulSoup(html,"lxml")
    return bsObj.find("div", {"id":"bodyContent"}).findAll("a", href=re.compile("^(/wiki/)((?!:).)*$"))


links = getLinks("/wiki/Kevin_Bacon")
while len(links) > 0:
    newArticle = links[random.randint(0, len(links)-1)].attrs["href"]
    print(newArticle)
    links = getLinks(newArticle)

# %%
Funktion getLinks sucht in articleUrl alle Links die den WikipediaArtikellink Konventionen entsprechen
geben Liste mit passenden Links zurück

# %%
t = type(bsObj.find("div", {"id":"bodyContent"}))
print(t)
# Out:
# <class 'bs4.element.Tag'>

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re
pages = set()
def getLinks(pageUrl):
    global pages
    html = urlopen("http://en.wikipedia.org"+pageUrl)
    bsObj = BeautifulSoup(html)
    for link in bsObj.findAll("a", href=re.compile("^(/wiki/)")):
        if 'href' in link.attrs:
            if link.attrs['href'] not in pages:
                #We have encountered a new page
                newPage = link.attrs['href']
                print(newPage)
                pages.add(newPage)
                getLinks(newPage)
                getLinks("")

# %% [markdown]
# Durchsucht eine definierte Wikipedia Seite,
# global pages speichert alle bereits durchsuchten link.attrs['href']
# geht sicher dass keine Seite zweimal durchsucht wird
# ACHTUNG: Algorithmus ist rekursiv (getLinks(newPage)) -> würde versuchen Wikipedia endlos zu durchsuchen!

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re
pages = set()
def getLinks(pageUrl):
    global pages
    html = urlopen("http://en.wikipedia.org"+pageUrl)
    bsObj = BeautifulSoup(html)
    try:
        print(bsObj.h1.get_text())
        print(bsObj.find(id ="mw-content-text").findAll("p")[0])
        print(bsObj.find(id="ca-edit").find("span").find("a").attrs['href'])
    except AttributeError:
        print("This page is missing something! No worries though!")
        for link in bsObj.findAll("a", href=re.compile("^(/wiki/)")):
            if 'href' in link.attrs:
                if link.attrs['href'] not in pages:
            #We have encountered a new page
                    newPage = link.attrs['href']
                    print("----------------\n"+newPage)
                    pages.add(newPage)
                    getLinks(newPage)
                    getLinks("")

# %% [markdown]
# Modifizierte Version vom Webcrawler

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re
import datetime
import random
pages = set()
random.seed(datetime.datetime.now())
#Retrieves a list of all Internal links found on a page
def getInternalLinks(bsObj, includeUrl):
    internalLinks = []
#Finds all links that begin with a "/"
    for link in bsObj.findAll("a", href=re.compile("^(/|.*"+includeUrl+")")):
        if link.attrs['href'] is not None:
            if link.attrs['href'] not in internalLinks:
                internalLinks.append(link.attrs['href'])
                return internalLinks

# %% [markdown]
# Webcrawler für interne Links

# %%
#Retrieves a list of all external links found on a page
def getExternalLinks(bsObj, excludeUrl):
    externalLinks = []
#Finds all links that start with "http" or "www" that do
#not contain the current URL
    for link in bsObj.findAll("a",href=re.compile("^(http|www)((?!"+excludeUrl+").)*$")):
        if link.attrs['href'] is not None:
            if link.attrs['href'] not in externalLinks:
                externalLinks.append(link.attrs['href'])
                return externalLinks

# %% [markdown]
# Webcrawler-Funktion für externe Links

# %%
def splitAddress(address):
    addressParts = address.replace("http://", "").split("/")
    return addressParts
def getRandomExternalLink(startingPage):
    html = urlopen(startingPage)
    bsObj = BeautifulSoup(html)
    externalLinks = getExternalLinks(bsObj, splitAddress(startingPage)[0])
    if len(externalLinks) == 0:
        internalLinks = getInternalLinks(startingPage)
        return getNextExternalLink(internalLinks[random.randint(0,
        len(internalLinks)-1)])
    else:
        return externalLinks[random.randint(0, len(externalLinks)-1)]
def followExternalOnly(startingSite):
    externalLink = getRandomExternalLink("http://oreilly.com")
    print("Random external link is: "+externalLink)
    followExternalOnly(externalLink)
    followExternalOnly("http://oreilly.com")

# %% [markdown]
# Weitere Hilfsfunktionen <br>
# getRandomExternalLink: wie der Name sagt, such zufällige externe Links

# %%
allExtLinks = set()
allIntLinks = set()
def getAllExternalLinks(siteUrl):
    html = urlopen(siteUrl)
    bsObj = BeautifulSoup(html)
    internalLinks = getInternalLinks(bsObj,splitAddress(siteUrl)[0])
    externalLinks = getExternalLinks(bsObj,splitAddress(siteUrl)[0])
    for link in externalLinks:
        if link not in allExtLinks:
            allExtLinks.add(link)
            print(link)
    for link in internalLinks:
        if link not in allIntLinks:
            print("About to get link: "+link)
            allIntLinks.add(link)
            getAllExternalLinks(link)

# %% [markdown]
# Hilfsfunktion: Sammelt eine Liste aller internen/externen Links einer Seite

# %% [markdown]
# redirects: es gibt zwei Arten von redirects, dh eine web page kann von verschiedenen domain-adressen aus angesehen werden:<br>
# Server-seitig: URL geändert bevor Seite geladen<br>
# Client-seitig: eg. "sie werden in 10 sek verbunden", Seite geladen bevor auf eine neue Seite weitergleitet wird

# %% [markdown]
# Scrapy: python library zum webscrapen.<br>
# startbefehl: scrapy startproject [Projektname]<br>
# Beispielstruktur eines solchenprojektes wenn angelegt:
# scrapy.cfg<br>
# Ordner wikiSpider<br>
# — __init.py__<br>
# — items.py<br>
# — pipelines.py<br>
# — settings.py<br>
# — spiders<br>
#
# Eine Datei "items.py" wird im wikiSpider Ordner definiert:

# %%
from scrapy import Item, Field
class Article(Item):
# define the fields for your item here like:
# name = scrapy.Field()
    title = Field()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-38-74d927442cce> in <module>()
# ----> 1 from scrapy import Item, Field
#       2 class Article(Item):
#       3 # define the fields for your item here like:
#       4 # name = scrapy.Field()
#       5     title = Field()
#
# ModuleNotFoundError: No module named 'scrapy'
